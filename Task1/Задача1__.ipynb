# %%
import mfem.ser as mfem
import numpy as np
import pandas as pd
from scipy.spatial.distance import cdist

# %% [markdown]
# ### Вариант 13

# %% [markdown]
# ## Сильная и слабая формы задачи

# %% [markdown]
# ### Сильная формулировка
# ### Задача теплопроводности в стационарной форме
#
# Уравнение теплопроводности:
#
# $$
# -\nabla \cdot (k(x) \nabla T(x)) = q(x), \quad x \in \Omega
# $$
#
# где:
# - $T(x)$ — температура в точке \( x \), зависящая от координат;
# - $k(x)$ — коэффициент теплопроводности, который зависит от материала (воздух или алюминий);
# - $q(x)$ — источник тепла.
#
# ### Граничные условия
#
# 1. **Температура на поверхности окна :**
#    $$ T(x) |_{\partial \Omega_D} = -10.0, \quad x \in \partial \Omega_D $$
#    Температура на границе, соответствующей окну, фиксирована и равна -10.0°C.
#
# 2. **Граничное условие Неймана на стенах:**
#    $$ \frac{\partial T(x)}{\partial n} |_{\partial \Omega_N} = 0, \quad x \in \partial \Omega_N $$
#    Поток тепла через стены отсутствует.
#
# ### Свойства материалов
#
# 1. **Коэффициент теплопроводности $k(x)$:**
#    $$ k(x) =
#    \begin{cases}
#       0.022, & \text{если } x \in \text{воздух}, \\
#       209.3, & \text{если } x \in \text{алюминий (радиатор)}.
#    \end{cases}
#    $$
#
# 2. **Источник тепла $q(x)$:**
#    $$ q(x) =
#    \begin{cases}
#       0, & \text{если } x \in \text{воздух}, \\
#       heat, & \text{если } x \in \text{алюминий (радиатор)}.
#    \end{cases}
#    $$
#
#
# ### Интерпретация задачи
#
# Задача описывает теплопроводность в комнате с радиатором, сделанным из алюминия, который выделяет тепло. Граничные условия задают температуру на окне и отсутствие теплового потока на стенах. Важно учитывать различные коэффициенты теплопроводности для воздуха и алюминия, а также источник тепла - радиатор.

# %% [markdown]
# ### Слабая формулировка
#
# Найти $$ T \in V_D = \{f \in H^1(\Omega): f|_{\partial \Omega_D} = -10\}$$
# Удовлетворяющую уравнению
# \
# $$\int_{\Omega} k \nabla T \cdot \nabla \upsilon dV = \int_{\Omega} q \upsilon dV, \forall \upsilon \in V_0 = \{f \in H^1(\Omega): f|_{\partial \Omega_D} = 0\}$$

# %% [markdown]
# ## Построение модели: FreeCAD + GMSH
# ### Построены 3 разные сетки

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "Screenshot%20from%202024-11-18%2018-10-53.png", width=800, height=800)
# Out:
# <img src="Screenshot%20from%202024-11-18%2018-10-53.png" width="800" height="800"/>

# %%
Image(url= "Screenshot%20from%202024-11-18%2018-12-14.png", width=800, height=800)
# Out:
# <img src="Screenshot%20from%202024-11-18%2018-12-14.png" width="800" height="800"/>

# %%
Image(url= "Screenshot%20from%202024-11-18%2018-14-26.png", width=800, height=800)
# Out:
# <img src="Screenshot%20from%202024-11-18%2018-14-26.png" width="800" height="800"/>

# %% [markdown]
# ## Код

# %%
Image(url= "9d8e942s-960 (1).jpg", width=500, height=500)
# Out:
# <img src="9d8e942s-960 (1).jpg" width="500" height="500"/>

# %% [markdown]
# ### Получение решения

# %%
def solve(mesh, fespace, heat):
    """
    Решение задачи теплопередачи методом конечных элементов (FEM) с учетом граничных условий Дирихле и Неймана.
    
    Эта функция решает задачу теплопередачи в области, с учетом различных теплопроводностей для разных материалов.
    Используются граничные условия:
    - Дирихле: температура на окне и стенах.
    - Нейман: отсутствие потока тепла через стены.

    :param mesh: **mfem.Mesh** — сетка, определяющая геометрию области. 
    
    :param fespace: **mfem.FiniteElementSpace** — пространство конечных элементов. Это пространство, в котором будет решаться задача теплопередачи.
    
    :param heat: **float** — значение источника тепла, который применяется в радиаторе (алюминиевый радиатор). Это значение определяет мощность источника тепла, добавляемую в соответствующую часть области.

    :return: **mfem.GridFunction** — решение задачи в виде функции сетки, где значения представляют температуры в узлах сетки.
    """
    
    t1 = mfem.ConstantCoefficient(-10.0) # Температура на окне 
    t2 = mfem.ConstantCoefficient(0) 
    
    ess_bdr1 = mfem.intArray([0]*mesh.bdr_attributes.Size()) 
    ess_bdr1[0] = 1 # Окно 
    
    # Граничные условия Неймана для всех стен  - отсуствие потока тепла через стенки
    ess_bdr2 = mfem.intArray([0]*mesh.bdr_attributes.Size())
    ess_bdr2[1] = 1 # Стенки
    
    # Применение граничных условий Дирихле
    ess_tdof_list = mfem.intArray()
    ess_bdr = mfem.intArray([1]*mesh.bdr_attributes.Size())
    ess_bdr[1] = 0
    fespace.GetEssentialTrueDofs(ess_bdr, ess_tdof_list)
        
    
    # Теплопроводности для разных областей
    k_air = 0.022  # Теплопроводность для воздуха
    k_metal = 209.3 # Теплопроводность для радиатора (алюминий)
    
    # Tеплопроводности для разных областей
    k_values = mfem.Vector(mesh.attributes.Max())
    k_values[0] = k_air  # Воздух в комнате
    k_values[1] = k_metal  # Радиатор
    
    # Создаем коэффициент теплопроводности 
    k_pw_const = mfem.PWConstCoefficient(k_values)

    class VolumeSource(mfem.PyCoefficient):
        def __init__(self, mesh):
            super().__init__()
            self.mesh = mesh

        def Eval(self, Ttr, ip):
            element_attribute = Ttr.ElementNo

            if self.mesh.GetAttribute(element_attribute) == 2:
                return heat
            elif self.mesh.GetAttribute(element_attribute) == 1:
                return 0.0
            else:
                return 0.0

    rhs = VolumeSource(mesh)

    a = mfem.BilinearForm(fespace)
    a.AddDomainIntegrator(mfem.DiffusionIntegrator(k_pw_const))
    a.Assemble()
    
    # Создание линейной формы для правой части
    b = mfem.LinearForm(fespace)
    b.AddDomainIntegrator(mfem.DomainLFIntegrator(rhs))
    b.AddDomainIntegrator(mfem.BoundaryLFIntegrator(t2), ess_bdr2)
    b.Assemble()
    
    # Задание граничных условий Дирихле
    x = mfem.GridFunction(fespace)
    x.Assign(0.0) # Начальное значение температуры во всей области
    x.ProjectBdrCoefficient(t1, ess_bdr1)
    
    # Формирование линейной системы (AX=B)
    A = mfem.OperatorPtr()
    B = mfem.Vector()
    X = mfem.Vector()
    a.FormLinearSystem(ess_tdof_list, x, b, A, X, B)
    
    AA = mfem.OperatorHandle2SparseMatrix(A)
    M = mfem.GSSmoother(AA)
    mfem.PCG(AA, M, B, X, 1, 500, 1e-12, 0.0)
    a.RecoverFEMSolution(X, b, x)

    return x

# %%
def save_file(mesh, x, file_name):
    
    pd = mfem.ParaViewDataCollection(file_name, mesh)
    pd.SetPrefixPath("ParaView")
    pd.RegisterField("temp", x)
    pd.Save()

# %%
def find_closest_vertex(verts, point):
    
    distances = cdist([point], verts)  
    index = np.argmin(distances)
    return index

# %% [markdown]
# ### Расчет нужной мощности радиатора

# %%
def find_f_newton(mesh, fespace, centre, temp_goal, heat_guess, tolerance, epsilon=1e-3, max_iterations=100):
    """
    Метод Ньютона для нахождения значения f, при котором температура в точке centre будет близка к temp_goal.

    :param mesh: Сетка.
    :param fespace: Пространство конечных элементов.
    :param centre: Точка, в которой нужно достичь целевой температуры.
    :param temp_goal: Целевая температура.
    :param heat_guess: Начальная догадка для значения параметра источника тепла.
    :param tolerance: Точность, с которой должна быть достигнута целевая температура.
    :param epsilon: Малое число для вычисления производной (по умолчанию 1e-3).
    :param max_iterations: Максимальное количество итераций для метода Ньютона.
    
    :return: Решение x, температура в точке, найденное значение мощности, координаты вершины
    """

    heat_source = heat_guess  
    iteration = 0
    verts = mesh.GetVertexArray()

    # Найдем индекс ближайшей вершины к заданной точке (centre)
    index_nearest_centre = find_closest_vertex(verts, centre)

    # Итерации метода Ньютона
    while iteration < max_iterations:
        # Решаем задачу методом конечных элементов для текущего значения f
        x = solve(mesh, fespace, heat_source)
        sol = x.GetDataArray()

        # Получаем текущую температуру в ближайшей вершине
        current_temp = sol[index_nearest_centre]
        print("Temperature: ", current_temp)
        # Вычисляем ошибку
        error = current_temp - temp_goal

        # Если ошибка достаточно мала, выходим из цикла
        if abs(error) < tolerance:
            break

        x1 = solve(mesh, fespace, heat_source + epsilon)
        sol1 = x1.GetDataArray()
        temp1 = sol1[index_nearest_centre]
        derivative = (temp1 - current_temp) / epsilon

        # Обновляем значение heat_source с использованием формулы Ньютона
        heat_source_next = heat_source - error / derivative
        heat_source = heat_source_next
        iteration += 1

    return x, current_temp, heat_source, verts[index_nearest_centre]

# %% [markdown]
# ### Расчет максимальной температуры радиатора

# %%
def find_max_radiator_temp(radiator_position, mesh, x):
    """
    Функция находит максимальную температуру в радиаторе, которая определяется
    температурой вершин, попадающих в заданную область (позицией радиатора) на сетке.

    Аргументы:
    radiator_position (tuple): ((min_x, min_y, min_z), (max_x, max_y, max_z)).
    mesh (object): Объект сетки (mesh), содержащий информацию о вершинах.
    sol (list): Список или массив температур, соответствующих каждой вершине сетки.

    Возвращаемое значение:
    float: Максимальная температура среди вершин, попадающих в заданную область.
    """
    
    verts = mesh.GetVertexArray()  
    sol = x.GetDataArray()
    temp_radiator_max = 0 

    for i, vertex in enumerate(verts):
        if all(radiator_position[0][j] <= vertex[j] <= radiator_position[1][j] for j in range(0, 3)):
            temp_radiator_max = max(temp_radiator_max, sol[i])

    return temp_radiator_max

# %%
def calculate_for_mesh(meshname, filename):
    
    temp_goal = 19.0
    centre_coord = np.array([2350, 2550, 1550])
    radiator_position = ((1800, 0, 200),(2900, 150, 800))
    heat_guess = 1e-6
    tolerance = 1e-3
    
    mesh = mfem.Mesh(meshname, 1, 1) 
    fec = mfem.H1_FECollection(1, mesh.Dimension())   
    fespace = mfem.FiniteElementSpace(mesh, fec)
    x, current_temp, heat_source, verts = find_f_newton(mesh, fespace, centre_coord, temp_goal, heat_guess, tolerance)
    save_file(mesh, x, filename)
    
    vertex = f"({verts[0]:.0f}, {verts[1]:.0f}, {verts[2]:.0f})"
    max_temp = find_max_radiator_temp(radiator_position, mesh, x)
    return [fespace.GetTrueVSize(), current_temp, heat_source, vertex, max_temp]

# %% [markdown]
# ### Вычисления и результаты

# %%
sol1 = calculate_for_mesh('mesh1_', 'mesh1')
sol2 = calculate_for_mesh('mesh2_', 'mesh2')
sol3 = calculate_for_mesh('mesh3_', 'mesh3')
# Out:
# Average reduction factor = 0.766175
#    Iteration :   0  (B r, r) = 12459.7
#    Iteration :   1  (B r, r) = 1984.28
# Temperature:  -9.51222709423543
#    Iteration :   2  (B r, r) = 740.629
#    Iteration :   3  (B r, r) = 392.772
#    Iteration :   4  (B r, r) = 245.013
#    Iteration :   5  (B r, r) = 171.736
#    Iteration :   6  (B r, r) = 131.635
#    Iteration :   7  (B r, r) = 113.723
#    Iteration :   8  (B r, r) = 103.061
#    Iteration :   9  (B r, r) = 96.5039
#    Iteration :  10  (B r, r) = 87.8264
#    Iteration :  11  (B r, r) = 74.0759
#    Iteration :  12  (B r, r) = 62.7986
#    Iteration :  13  (B r, r) = 50.5698
#    Iteration :  14  (B r, r) = 44.7376
#    Iteration :  15  (B r, r) = 38.5191
#    Iteration :  16  (B r, r) = 36.7871
#    Iteration :  17  (B r, r) = 33.2997
#    Iteration :  18  (B r, r) = 34.7346
#    Iteration :  19  (B r, r) = 47.8148
#    Iteration :  20  (B r, r) = 73.3512
#    Iteration :  21  (B r, r) = 94.9521
#    Iteration :  22  (B r, r) = 98.6307
#    Iteration :  23  (B r, r) = 79.3129
#    Iteration :  24  (B r, r) = 67.0309
#    Iteration :  25  (B r, r) = 58.5897
#    Iteration :  26  (B r, r) = 47.2672
#    Iteration :  27  (B r, r) = 32.4762
#    Iteration :  28  (B r, r) = 16.925
#    Iteration :  29  (B r, r) = 8.13893
#    Iteration :  30  (B r, r) = 4.02672
#    Iteration :  31  (B r, r) = 2.29274
#    Iteration :  32  (B r, r) = 1.40606
#    Iteration :  33  (B r, r) = 0.999173
#    Iteration :  34  (B r, r) = 0.902444
#    Iteration :  35  (B r, r) = 0.844148
#    Iteration :  36  (B r, r) = 0.70982
#    Iteration :  37  (B r, r) = 0.543261
#    Iteration :  38  (B r, r) = 0.503868
#    Iteration :  39  (B r, r) = 0.661407
#    Iteration :  40  (B r, r) = 1.00946
#    Iteration :  41  (B r, r) = 1.23303
#    Iteration :  42  (B r, r) = 1.63405
#    Iteration :  43  (B r, r) = 3.37226
#    Iteration :  44  (B r, r) = 6.77689
#    Iteration :  45  (B r, r) = 10.2056
#    Iteration :  46  (B r, r) = 15.5717
#    Iteration :  47  (B r, r) = 21.4773
#    Iteration :  48  (B r, r) = 33.7198
#    Iteration :  49  (B r, r) = 64.4795
#    Iteration :  50  (B r, r) = 84.0206
#    Iteration :  51  (B r, r) = 96.7248
#    Iteration :  52  (B r, r) = 115.565
#    Iteration :  53  (B r, r) = 99.138
#    Iteration :  54  (B r, r) = 66.7043
#    Iteration :  55  (B r, r) = 48.1428
#    Iteration :  56  (B r, r) = 48.1937
#    Iteration :  57  (B r, r) = 61.8431
#    Iteration :  58  (B r, r) = 87.8261
#    Iteration :  59  (B r, r) = 94.7415
#    Iteration :  60  (B r, r) = 78.0407
#    Iteration :  61  (B r, r) = 47.7765
#    Iteration :  62  (B r, r) = 30.5695
#    Iteration :  63  (B r, r) = 17.5133
#    Iteration :  64  (B r, r) = 11.2187
#    Iteration :  65  (B r, r) = 5.9393
#    Iteration :  66  (B r, r) = 2.83461
#    Iteration :  67  (B r, r) = 1.82114
#    Iteration :  68  (B r, r) = 1.59747
#    Iteration :  69  (B r, r) = 1.3503
#    Iteration :  70  (B r, r) = 0.955122
#    Iteration :  71  (B r, r) = 0.678073
#    Iteration :  72  (B r, r) = 0.407167
#    Iteration :  73  (B r, r) = 0.177117
#    Iteration :  74  (B r, r) = 0.08771
#    Iteration :  75  (B r, r) = 0.0564509
#    Iteration :  76  (B r, r) = 0.0380422
#    Iteration :  77  (B r, r) = 0.0265798
#    Iteration :  78  (B r, r) = 0.017797
#    Iteration :  79  (B r, r) = 0.0102655
#    Iteration :  80  (B r, r) = 0.00502552
#    Iteration :  81  (B r, r) = 0.00217722
#    Iteration :  82  (B r, r) = 0.000885476
#    Iteration :  83  (B r, r) = 0.000314058
#    Iteration :  84  (B r, r) = 0.000112065
#    Iteration :  85  (B r, r) = 5.00059e-05
#    Iteration :  86  (B r, r) = 3.16893e-05
#    Iteration :  87  (B r, r) = 2.186e-05
#    Iteration :  88  (B r, r) = 1.36365e-05
#    Iteration :  89  (B r, r) = 6.7239e-06
#    Iteration :  90  (B r, r) = 3.28831e-06
#    Iteration :  91  (B r, r) = 1.49921e-06
#    Iteration :  92  (B r, r) = 6.57273e-07
#    Iteration :  93  (B r, r) = 2.65657e-07
#    Iteration :  94  (B r, r) = 1.19005e-07
#    Iteration :  95  (B r, r) = 5.24058e-08
#    Iteration :  96  (B r, r) = 2.42345e-08
#    Iteration :  97  (B r, r) = 1.59384e-08
#    Iteration :  98  (B r, r) = 1.11125e-08
# Average reduction factor = 0.868004
#    Iteration :   0  (B r, r) = 14762.3
#    Iteration :   1  (B r, r) = 5157.64
#    Iteration :   2  (B r, r) = 8175.53
#    Iteration :   3  (B r, r) = 19953.3
#    Iteration :   4  (B r, r) = 45977.1
#    Iteration :   5  (B r, r) = 95400.3
#    Iteration :   6  (B r, r) = 180170
#    Iteration :   7  (B r, r) = 315545
#    Iteration :   8  (B r, r) = 492938
#    Iteration :   9  (B r, r) = 702765
#    Iteration :  10  (B r, r) = 894833
#    Iteration :  11  (B r, r) = 1.02305e+06
#    Iteration :  12  (B r, r) = 1.12869e+06
#    Iteration :  13  (B r, r) = 1.17992e+06
#    Iteration :  14  (B r, r) = 1.35173e+06
#    Iteration :  15  (B r, r) = 1.46958e+06
#    Iteration :  16  (B r, r) = 1.68676e+06
#    Iteration :  17  (B r, r) = 1.72251e+06
#    Iteration :  18  (B r, r) = 1.9226e+06
#    Iteration :  19  (B r, r) = 2.4432e+06
#    Iteration :  20  (B r, r) = 2.69005e+06
#    Iteration :  21  (B r, r) = 2.11599e+06
#    Iteration :  22  (B r, r) = 1.38144e+06
#    Iteration :  23  (B r, r) = 812296
#    Iteration :  24  (B r, r) = 592386
#    Iteration :  25  (B r, r) = 489241
#    Iteration :  26  (B r, r) = 407967
#    Iteration :  27  (B r, r) = 327572
#    Iteration :  28  (B r, r) = 246285
#    Iteration :  29  (B r, r) = 227690
#    Iteration :  30  (B r, r) = 278872
#    Iteration :  31  (B r, r) = 448854
#    Iteration :  32  (B r, r) = 741173
#    Iteration :  33  (B r, r) = 1.17346e+06
#    Iteration :  34  (B r, r) = 1.65941e+06
#    Iteration :  35  (B r, r) = 1.67187e+06
#    Iteration :  36  (B r, r) = 1.24511e+06
#    Iteration :  37  (B r, r) = 834705
#    Iteration :  38  (B r, r) = 658964
#    Iteration :  39  (B r, r) = 576998
#    Iteration :  40  (B r, r) = 414987
#    Iteration :  41  (B r, r) = 226253
#    Iteration :  42  (B r, r) = 144233
#    Iteration :  43  (B r, r) = 116570
#    Iteration :  44  (B r, r) = 70022.4
#    Iteration :  45  (B r, r) = 34738.4
#    Iteration :  46  (B r, r) = 20073.5
#    Iteration :  47  (B r, r) = 11311.4
#    Iteration :  48  (B r, r) = 7670.19
#    Iteration :  49  (B r, r) = 5629.19
#    Iteration :  50  (B r, r) = 2917.06
#    Iteration :  51  (B r, r) = 1700.9
#    Iteration :  52  (B r, r) = 1082
#    Iteration :  53  (B r, r) = 564.097
#    Iteration :  54  (B r, r) = 298.141
#    Iteration :  55  (B r, r) = 199.267
#    Iteration :  56  (B r, r) = 184.598
#    Iteration :  57  (B r, r) = 200.843
#    Iteration :  58  (B r, r) = 224.958
#    Iteration :  59  (B r, r) = 191.344
#    Iteration :  60  (B r, r) = 126.967
#    Iteration :  61  (B r, r) = 62.8234
#    Iteration :  62  (B r, r) = 34.3229
#    Iteration :  63  (B r, r) = 18.437
#    Iteration :  64  (B r, r) = 12.1852
#    Iteration :  65  (B r, r) = 6.84465
#    Iteration :  66  (B r, r) = 3.34583
#    Iteration :  67  (B r, r) = 2.16772
#    Iteration :  68  (B r, r) = 1.91613
#    Iteration :  69  (B r, r) = 1.63241
#    Iteration :  70  (B r, r) = 1.15071
#    Iteration :  71  (B r, r) = 0.779576
#    Iteration :  72  (B r, r) = 0.443926
#    Iteration :  73  (B r, r) = 0.192509
#    Iteration :  74  (B r, r) = 0.0978824
#    Iteration :  75  (B r, r) = 0.0624301
#    Iteration :  76  (B r, r) = 0.0398327
#    Iteration :  77  (B r, r) = 0.0268846
#    Iteration :  78  (B r, r) = 0.018196
#    Iteration :  79  (B r, r) = 0.0106025
#    Iteration :  80  (B r, r) = 0.00507784
#    Iteration :  81  (B r, r) = 0.0021245
#    Iteration :  82  (B r, r) = 0.000865388
#    Iteration :  83  (B r, r) = 0.000325685
#    Iteration :  84  (B r, r) = 0.000125389
#    Iteration :  85  (B r, r) = 5.79085e-05
#    Iteration :  86  (B r, r) = 3.55894e-05
#    Iteration :  87  (B r, r) = 2.36984e-05
#    Iteration :  88  (B r, r) = 1.54424e-05
#    Iteration :  89  (B r, r) = 8.05204e-06
#    Iteration :  90  (B r, r) = 3.85436e-06
#    Iteration :  91  (B r, r) = 1.58367e-06
#    Iteration :  92  (B r, r) = 6.37347e-07
#    Iteration :  93  (B r, r) = 2.57515e-07
#    Iteration :  94  (B r, r) = 1.21314e-07
#    Iteration :  95  (B r, r) = 5.33696e-08
#    Iteration :  96  (B r, r) = 2.26626e-08
#    Iteration :  97  (B r, r) = 1.3281e-08
# Average reduction factor = 0.866777
#    Iteration :   0  (B r, r) = 12467.7
#    Iteration :   1  (B r, r) = 1993.47
# Temperature:  19.00000011075222
#    Iteration :   2  (B r, r) = 753.185
#    Iteration :   3  (B r, r) = 409.518
#    Iteration :   4  (B r, r) = 266.204
#    Iteration :   5  (B r, r) = 197.998
#    Iteration :   6  (B r, r) = 163.927
#    Iteration :   7  (B r, r) = 154.861
#    Iteration :   8  (B r, r) = 154.35
#    Iteration :   9  (B r, r) = 159.249
#    Iteration :  10  (B r, r) = 159.937
#    Iteration :  11  (B r, r) = 150
#    Iteration :  12  (B r, r) = 143.052
#    Iteration :  13  (B r, r) = 131.669
#    Iteration :  14  (B r, r) = 134.935
#    Iteration :  15  (B r, r) = 135.76
#    Iteration :  16  (B r, r) = 151.845
#    Iteration :  17  (B r, r) = 160.638
#    Iteration :  18  (B r, r) = 194.156
#    Iteration :  19  (B r, r) = 299.086
#    Iteration :  20  (B r, r) = 489.087
#    Iteration :  21  (B r, r) = 650.907
#    Iteration :  22  (B r, r) = 685.176
#    Iteration :  23  (B r, r) = 560.73
#    Iteration :  24  (B r, r) = 489.187
#    Iteration :  25  (B r, r) = 446.041
#    Iteration :  26  (B r, r) = 380.158
#    Iteration :  27  (B r, r) = 283.594
#    Iteration :  28  (B r, r) = 171.259
#    Iteration :  29  (B r, r) = 108.758
#    Iteration :  30  (B r, r) = 86.1291
#    Iteration :  31  (B r, r) = 94.5884
#    Iteration :  32  (B r, r) = 125.668
#    Iteration :  33  (B r, r) = 196.865
#    Iteration :  34  (B r, r) = 352.867
#    Iteration :  35  (B r, r) = 568.153
#    Iteration :  36  (B r, r) = 761.322
#    Iteration :  37  (B r, r) = 916.42
#    Iteration :  38  (B r, r) = 1296.45
#    Iteration :  39  (B r, r) = 2301.91
#    Iteration :  40  (B r, r) = 4044.47
#    Iteration :  41  (B r, r) = 5093.33
#    Iteration :  42  (B r, r) = 6525.37
#    Iteration :  43  (B r, r) = 11349.2
#    Iteration :  44  (B r, r) = 15094.6
#    Iteration :  45  (B r, r) = 12983.2
#    Iteration :  46  (B r, r) = 10442.7
#    Iteration :  47  (B r, r) = 7336.87
#    Iteration :  48  (B r, r) = 5843.28
#    Iteration :  49  (B r, r) = 4730.57
#    Iteration :  50  (B r, r) = 2526.09
#    Iteration :  51  (B r, r) = 1470.28
#    Iteration :  52  (B r, r) = 960.225
#    Iteration :  53  (B r, r) = 509.021
#    Iteration :  54  (B r, r) = 255.887
#    Iteration :  55  (B r, r) = 155.907
#    Iteration :  56  (B r, r) = 136.934
#    Iteration :  57  (B r, r) = 152.454
#    Iteration :  58  (B r, r) = 178.938
#    Iteration :  59  (B r, r) = 154.764
#    Iteration :  60  (B r, r) = 105.575
#    Iteration :  61  (B r, r) = 56.9859
#    Iteration :  62  (B r, r) = 33.9342
#    Iteration :  63  (B r, r) = 18.6179
#    Iteration :  64  (B r, r) = 11.6476
#    Iteration :  65  (B r, r) = 6.08871
#    Iteration :  66  (B r, r) = 2.89404
#    Iteration :  67  (B r, r) = 1.85836
#    Iteration :  68  (B r, r) = 1.62903
#    Iteration :  69  (B r, r) = 1.37295
#    Iteration :  70  (B r, r) = 0.96767
#    Iteration :  71  (B r, r) = 0.684616
#    Iteration :  72  (B r, r) = 0.409853
#    Iteration :  73  (B r, r) = 0.177929
#    Iteration :  74  (B r, r) = 0.0880097
#    Iteration :  75  (B r, r) = 0.0566189
#    Iteration :  76  (B r, r) = 0.0381403
#    Iteration :  77  (B r, r) = 0.0266116
#    Iteration :  78  (B r, r) = 0.017785
#    Iteration :  79  (B r, r) = 0.0102468
#    Iteration :  80  (B r, r) = 0.00501617
#    Iteration :  81  (B r, r) = 0.00217399
#    Iteration :  82  (B r, r) = 0.000884261
#    Iteration :  83  (B r, r) = 0.000313593
#    Iteration :  84  (B r, r) = 0.000111883
#    Iteration :  85  (B r, r) = 4.99499e-05
#    Iteration :  86  (B r, r) = 3.17057e-05
#    Iteration :  87  (B r, r) = 2.18986e-05
#    Iteration :  88  (B r, r) = 1.36548e-05
#    Iteration :  89  (B r, r) = 6.72125e-06
#    Iteration :  90  (B r, r) = 3.28197e-06
#    Iteration :  91  (B r, r) = 1.49581e-06
#    Iteration :  92  (B r, r) = 6.55388e-07
#    Iteration :  93  (B r, r) = 2.64339e-07
#    Iteration :  94  (B r, r) = 1.18019e-07
#    Iteration :  95  (B r, r) = 5.17918e-08
#    Iteration :  96  (B r, r) = 2.38845e-08
#    Iteration :  97  (B r, r) = 1.57013e-08
#    Iteration :  98  (B r, r) = 1.09852e-08
# Average reduction factor = 0.867951
#    Iteration :   0  (B r, r) = 13245.5
#    Iteration :   1  (B r, r) = 1706.56
# Temperature:  -9.552451029189603
#    Iteration :   2  (B r, r) = 635.006
#    Iteration :   3  (B r, r) = 318.42
#    Iteration :   4  (B r, r) = 214.882
#    Iteration :   5  (B r, r) = 177.762
#    Iteration :   6  (B r, r) = 157.319
#    Iteration :   7  (B r, r) = 121.299
#    Iteration :   8  (B r, r) = 101.643
#    Iteration :   9  (B r, r) = 79.3553
#    Iteration :  10  (B r, r) = 60.032
#    Iteration :  11  (B r, r) = 53.6954
#    Iteration :  12  (B r, r) = 60.3442
#    Iteration :  13  (B r, r) = 96.9233
#    Iteration :  14  (B r, r) = 161.269
#    Iteration :  15  (B r, r) = 144.457
#    Iteration :  16  (B r, r) = 97.4263
#    Iteration :  17  (B r, r) = 60.6063
#    Iteration :  18  (B r, r) = 35.7656
#    Iteration :  19  (B r, r) = 16.132
#    Iteration :  20  (B r, r) = 6.44702
#    Iteration :  21  (B r, r) = 2.29015
#    Iteration :  22  (B r, r) = 1.06856
#    Iteration :  23  (B r, r) = 0.722712
#    Iteration :  24  (B r, r) = 0.435933
#    Iteration :  25  (B r, r) = 0.210106
#    Iteration :  26  (B r, r) = 0.115232
#    Iteration :  27  (B r, r) = 0.0904334
#    Iteration :  28  (B r, r) = 0.0997508
#    Iteration :  29  (B r, r) = 0.146768
#    Iteration :  30  (B r, r) = 0.287379
#    Iteration :  31  (B r, r) = 0.555481
#    Iteration :  32  (B r, r) = 1.06246
#    Iteration :  33  (B r, r) = 1.88054
#    Iteration :  34  (B r, r) = 2.69721
#    Iteration :  35  (B r, r) = 3.52081
#    Iteration :  36  (B r, r) = 5.40516
#    Iteration :  37  (B r, r) = 6.73344
#    Iteration :  38  (B r, r) = 8.90593
#    Iteration :  39  (B r, r) = 19.1937
#    Iteration :  40  (B r, r) = 53.5844
#    Iteration :  41  (B r, r) = 121.259
#    Iteration :  42  (B r, r) = 136.516
#    Iteration :  43  (B r, r) = 136.003
#    Iteration :  44  (B r, r) = 150.931
#    Iteration :  45  (B r, r) = 149.068
#    Iteration :  46  (B r, r) = 175.471
#    Iteration :  47  (B r, r) = 155.477
#    Iteration :  48  (B r, r) = 59.0353
#    Iteration :  49  (B r, r) = 22.6488
#    Iteration :  50  (B r, r) = 10.3028
#    Iteration :  51  (B r, r) = 4.25708
#    Iteration :  52  (B r, r) = 2.17575
#    Iteration :  53  (B r, r) = 1.47159
#    Iteration :  54  (B r, r) = 1.18364
#    Iteration :  55  (B r, r) = 0.9218
#    Iteration :  56  (B r, r) = 0.59943
#    Iteration :  57  (B r, r) = 0.58863
#    Iteration :  58  (B r, r) = 0.515988
#    Iteration :  59  (B r, r) = 0.365983
#    Iteration :  60  (B r, r) = 0.244413
#    Iteration :  61  (B r, r) = 0.20269
#    Iteration :  62  (B r, r) = 0.185304
#    Iteration :  63  (B r, r) = 0.148211
#    Iteration :  64  (B r, r) = 0.104611
#    Iteration :  65  (B r, r) = 0.0606479
#    Iteration :  66  (B r, r) = 0.0289117
#    Iteration :  67  (B r, r) = 0.00954352
#    Iteration :  68  (B r, r) = 0.00405248
#    Iteration :  69  (B r, r) = 0.00160438
#    Iteration :  70  (B r, r) = 0.000562312
#    Iteration :  71  (B r, r) = 0.00022652
#    Iteration :  72  (B r, r) = 9.44762e-05
#    Iteration :  73  (B r, r) = 2.77242e-05
#    Iteration :  74  (B r, r) = 7.44591e-06
#    Iteration :  75  (B r, r) = 2.96619e-06
#    Iteration :  76  (B r, r) = 1.77975e-06
#    Iteration :  77  (B r, r) = 1.3953e-06
#    Iteration :  78  (B r, r) = 1.05213e-06
#    Iteration :  79  (B r, r) = 4.81377e-07
#    Iteration :  80  (B r, r) = 1.54109e-07
#    Iteration :  81  (B r, r) = 5.7131e-08
#    Iteration :  82  (B r, r) = 1.84813e-08
#    Iteration :  83  (B r, r) = 7.10242e-09
# Average reduction factor = 0.843491
#    Iteration :   0  (B r, r) = 13853.3
#    Iteration :   1  (B r, r) = 2390.51
#    Iteration :   2  (B r, r) = 1848.67
#    Iteration :   3  (B r, r) = 2610.98
#    Iteration :   4  (B r, r) = 5033.29
#    Iteration :   5  (B r, r) = 9954.01
#    Iteration :   6  (B r, r) = 17498.9
#    Iteration :   7  (B r, r) = 24465.7
#    Iteration :   8  (B r, r) = 35599.3
#    Iteration :   9  (B r, r) = 46644.6
#    Iteration :  10  (B r, r) = 59437.4
#    Iteration :  11  (B r, r) = 86918.2
#    Iteration :  12  (B r, r) = 143758
#    Iteration :  13  (B r, r) = 289275
#    Iteration :  14  (B r, r) = 512885
#    Iteration :  15  (B r, r) = 462489
#    Iteration :  16  (B r, r) = 332435
#    Iteration :  17  (B r, r) = 242922
#    Iteration :  18  (B r, r) = 190135
#    Iteration :  19  (B r, r) = 140465
#    Iteration :  20  (B r, r) = 129893
#    Iteration :  21  (B r, r) = 165794
#    Iteration :  22  (B r, r) = 346351
#    Iteration :  23  (B r, r) = 830518
#    Iteration :  24  (B r, r) = 1.33661e+06
#    Iteration :  25  (B r, r) = 1.73858e+06
#    Iteration :  26  (B r, r) = 2.61737e+06
#    Iteration :  27  (B r, r) = 3.94166e+06
#    Iteration :  28  (B r, r) = 4.5565e+06
#    Iteration :  29  (B r, r) = 3.93076e+06
#    Iteration :  30  (B r, r) = 2.83443e+06
#    Iteration :  31  (B r, r) = 1.69175e+06
#    Iteration :  32  (B r, r) = 1.17964e+06
#    Iteration :  33  (B r, r) = 948154
#    Iteration :  34  (B r, r) = 900483
#    Iteration :  35  (B r, r) = 1.03704e+06
#    Iteration :  36  (B r, r) = 1.19969e+06
#    Iteration :  37  (B r, r) = 928695
#    Iteration :  38  (B r, r) = 801025
#    Iteration :  39  (B r, r) = 622382
#    Iteration :  40  (B r, r) = 324856
#    Iteration :  41  (B r, r) = 142135
#    Iteration :  42  (B r, r) = 88848.1
#    Iteration :  43  (B r, r) = 80628.4
#    Iteration :  44  (B r, r) = 53293.2
#    Iteration :  45  (B r, r) = 23720.8
#    Iteration :  46  (B r, r) = 12341
#    Iteration :  47  (B r, r) = 4810.62
#    Iteration :  48  (B r, r) = 2287.91
#    Iteration :  49  (B r, r) = 2275.92
#    Iteration :  50  (B r, r) = 2258.46
#    Iteration :  51  (B r, r) = 1395.11
#    Iteration :  52  (B r, r) = 779.354
#    Iteration :  53  (B r, r) = 318.9
#    Iteration :  54  (B r, r) = 123.852
#    Iteration :  55  (B r, r) = 46.5796
#    Iteration :  56  (B r, r) = 21.2304
#    Iteration :  57  (B r, r) = 13.5127
#    Iteration :  58  (B r, r) = 6.72691
#    Iteration :  59  (B r, r) = 3.26052
#    Iteration :  60  (B r, r) = 1.74078
#    Iteration :  61  (B r, r) = 1.14623
#    Iteration :  62  (B r, r) = 0.674128
#    Iteration :  63  (B r, r) = 0.341739
#    Iteration :  64  (B r, r) = 0.165886
#    Iteration :  65  (B r, r) = 0.0769003
#    Iteration :  66  (B r, r) = 0.0337132
#    Iteration :  67  (B r, r) = 0.01234
#    Iteration :  68  (B r, r) = 0.00683448
#    Iteration :  69  (B r, r) = 0.00387717
#    Iteration :  70  (B r, r) = 0.00220017
#    Iteration :  71  (B r, r) = 0.00144064
#    Iteration :  72  (B r, r) = 0.000835604
#    Iteration :  73  (B r, r) = 0.000352034
#    Iteration :  74  (B r, r) = 0.000188388
#    Iteration :  75  (B r, r) = 0.000102667
#    Iteration :  76  (B r, r) = 3.66274e-05
#    Iteration :  77  (B r, r) = 1.12952e-05
#    Iteration :  78  (B r, r) = 3.09798e-06
#    Iteration :  79  (B r, r) = 7.78782e-07
#    Iteration :  80  (B r, r) = 1.98087e-07
#    Iteration :  81  (B r, r) = 6.67773e-08
#    Iteration :  82  (B r, r) = 2.02753e-08
#    Iteration :  83  (B r, r) = 7.41534e-09
# Average reduction factor = 0.843482
#    Iteration :   0  (B r, r) = 13248
#    Iteration :   1  (B r, r) = 1709.17
# Temperature:  18.99999992281562
#    Iteration :   2  (B r, r) = 638.701
#    Iteration :   3  (B r, r) = 323.187
#    Iteration :   4  (B r, r) = 221.303
#    Iteration :   5  (B r, r) = 186.539
#    Iteration :   6  (B r, r) = 168.647
#    Iteration :   7  (B r, r) = 133.384
#    Iteration :   8  (B r, r) = 115.265
#    Iteration :   9  (B r, r) = 93.4092
#    Iteration :  10  (B r, r) = 74.1142
#    Iteration :  11  (B r, r) = 70.113
#    Iteration :  12  (B r, r) = 83.1799
#    Iteration :  13  (B r, r) = 138.954
#    Iteration :  14  (B r, r) = 236.096
#    Iteration :  15  (B r, r) = 214.486
#    Iteration :  16  (B r, r) = 147.627
#    Iteration :  17  (B r, r) = 95.0611
#    Iteration :  18  (B r, r) = 59.4772
#    Iteration :  19  (B r, r) = 30.0895
#    Iteration :  20  (B r, r) = 15.448
#    Iteration :  21  (B r, r) = 9.43294
#    Iteration :  22  (B r, r) = 10.5809
#    Iteration :  23  (B r, r) = 18.8963
#    Iteration :  24  (B r, r) = 29.2298
#    Iteration :  25  (B r, r) = 40.6677
#    Iteration :  26  (B r, r) = 71.922
#    Iteration :  27  (B r, r) = 159.278
#    Iteration :  28  (B r, r) = 363.827
#    Iteration :  29  (B r, r) = 819.892
#    Iteration :  30  (B r, r) = 1953.51
#    Iteration :  31  (B r, r) = 3930.09
#    Iteration :  32  (B r, r) = 7006.95
#    Iteration :  33  (B r, r) = 10282.8
#    Iteration :  34  (B r, r) = 11151.4
#    Iteration :  35  (B r, r) = 10674.7
#    Iteration :  36  (B r, r) = 11526
#    Iteration :  37  (B r, r) = 9539.07
#    Iteration :  38  (B r, r) = 8758.35
#    Iteration :  39  (B r, r) = 11229.9
#    Iteration :  40  (B r, r) = 12028.7
#    Iteration :  41  (B r, r) = 6785.04
#    Iteration :  42  (B r, r) = 2773.79
#    Iteration :  43  (B r, r) = 1695.61
#    Iteration :  44  (B r, r) = 1450.58
#    Iteration :  45  (B r, r) = 1231.07
#    Iteration :  46  (B r, r) = 1291.98
#    Iteration :  47  (B r, r) = 927.874
#    Iteration :  48  (B r, r) = 446.066
#    Iteration :  49  (B r, r) = 368.874
#    Iteration :  50  (B r, r) = 416.924
#    Iteration :  51  (B r, r) = 383.848
#    Iteration :  52  (B r, r) = 329.811
#    Iteration :  53  (B r, r) = 193.459
#    Iteration :  54  (B r, r) = 88.8396
#    Iteration :  55  (B r, r) = 34.5449
#    Iteration :  56  (B r, r) = 14.7059
#    Iteration :  57  (B r, r) = 8.78067
#    Iteration :  58  (B r, r) = 4.19414
#    Iteration :  59  (B r, r) = 1.9018
#    Iteration :  60  (B r, r) = 0.94794
#    Iteration :  61  (B r, r) = 0.62675
#    Iteration :  62  (B r, r) = 0.426231
#    Iteration :  63  (B r, r) = 0.256536
#    Iteration :  64  (B r, r) = 0.143204
#    Iteration :  65  (B r, r) = 0.0711197
#    Iteration :  66  (B r, r) = 0.0308734
#    Iteration :  67  (B r, r) = 0.00979347
#    Iteration :  68  (B r, r) = 0.00409498
#    Iteration :  69  (B r, r) = 0.00160661
#    Iteration :  70  (B r, r) = 0.000559236
#    Iteration :  71  (B r, r) = 0.000223319
#    Iteration :  72  (B r, r) = 9.19721e-05
#    Iteration :  73  (B r, r) = 2.62799e-05
#    Iteration :  74  (B r, r) = 6.50828e-06
#    Iteration :  75  (B r, r) = 2.15676e-06
#    Iteration :  76  (B r, r) = 1.00322e-06
#    Iteration :  77  (B r, r) = 6.65808e-07
#    Iteration :  78  (B r, r) = 5.62194e-07
#    Iteration :  79  (B r, r) = 3.34509e-07
#    Iteration :  80  (B r, r) = 1.27678e-07
#    Iteration :  81  (B r, r) = 5.16791e-08
#    Iteration :  82  (B r, r) = 1.74857e-08
#    Iteration :  83  (B r, r) = 6.85796e-09
# Average reduction factor = 0.843312
#    Iteration :   0  (B r, r) = 10096
#    Iteration :   1  (B r, r) = 1263.21
# Temperature:  -9.615521623310054
#    Iteration :   2  (B r, r) = 483.035
#    Iteration :   3  (B r, r) = 291.142
#    Iteration :   4  (B r, r) = 241.867
#    Iteration :   5  (B r, r) = 173.183
#    Iteration :   6  (B r, r) = 123.655
#    Iteration :   7  (B r, r) = 93.2454
#    Iteration :   8  (B r, r) = 79.3952
#    Iteration :   9  (B r, r) = 88.3943
#    Iteration :  10  (B r, r) = 166.77
#    Iteration :  11  (B r, r) = 187.204
#    Iteration :  12  (B r, r) = 122.577
#    Iteration :  13  (B r, r) = 73.2813
#    Iteration :  14  (B r, r) = 28.9916
#    Iteration :  15  (B r, r) = 7.77542
#    Iteration :  16  (B r, r) = 2.78763
#    Iteration :  17  (B r, r) = 1.66223
#    Iteration :  18  (B r, r) = 1.21695
#    Iteration :  19  (B r, r) = 0.756601
#    Iteration :  20  (B r, r) = 0.924095
#    Iteration :  21  (B r, r) = 2.04867
#    Iteration :  22  (B r, r) = 5.26096
#    Iteration :  23  (B r, r) = 15.8272
#    Iteration :  24  (B r, r) = 35.6183
#    Iteration :  25  (B r, r) = 74.9347
#    Iteration :  26  (B r, r) = 151.792
#    Iteration :  27  (B r, r) = 210.976
#    Iteration :  28  (B r, r) = 232.431
#    Iteration :  29  (B r, r) = 280.935
#    Iteration :  30  (B r, r) = 237.37
#    Iteration :  31  (B r, r) = 96.5911
#    Iteration :  32  (B r, r) = 48.9209
#    Iteration :  33  (B r, r) = 46.1397
#    Iteration :  34  (B r, r) = 36.1323
#    Iteration :  35  (B r, r) = 14.5434
#    Iteration :  36  (B r, r) = 4.05305
#    Iteration :  37  (B r, r) = 0.697172
#    Iteration :  38  (B r, r) = 0.203044
#    Iteration :  39  (B r, r) = 0.0544782
#    Iteration :  40  (B r, r) = 0.0194792
#    Iteration :  41  (B r, r) = 0.00597831
#    Iteration :  42  (B r, r) = 0.00188025
#    Iteration :  43  (B r, r) = 0.000521763
#    Iteration :  44  (B r, r) = 0.000300795
#    Iteration :  45  (B r, r) = 0.000177175
#    Iteration :  46  (B r, r) = 8.52909e-05
#    Iteration :  47  (B r, r) = 3.16937e-05
#    Iteration :  48  (B r, r) = 1.18472e-05
#    Iteration :  49  (B r, r) = 4.37976e-06
#    Iteration :  50  (B r, r) = 1.06312e-06
#    Iteration :  51  (B r, r) = 2.14576e-07
#    Iteration :  52  (B r, r) = 4.595e-08
#    Iteration :  53  (B r, r) = 1.17484e-08
#    Iteration :  54  (B r, r) = 2.47612e-09
# Average reduction factor = 0.764253
#    Iteration :   0  (B r, r) = 15028.3
#    Iteration :   1  (B r, r) = 7784.32
#    Iteration :   2  (B r, r) = 23001.2
#    Iteration :   3  (B r, r) = 75822.9
#    Iteration :   4  (B r, r) = 216666
#    Iteration :   5  (B r, r) = 424855
#    Iteration :   6  (B r, r) = 573381
#    Iteration :   7  (B r, r) = 837643
#    Iteration :   8  (B r, r) = 1.35863e+06
#    Iteration :   9  (B r, r) = 2.07135e+06
#    Iteration :  10  (B r, r) = 3.29296e+06
#    Iteration :  11  (B r, r) = 2.73655e+06
#    Iteration :  12  (B r, r) = 1.63329e+06
#    Iteration :  13  (B r, r) = 879625
#    Iteration :  14  (B r, r) = 603441
#    Iteration :  15  (B r, r) = 591465
#    Iteration :  16  (B r, r) = 1.07025e+06
#    Iteration :  17  (B r, r) = 2.03733e+06
#    Iteration :  18  (B r, r) = 3.79374e+06
#    Iteration :  19  (B r, r) = 3.0721e+06
#    Iteration :  20  (B r, r) = 2.08708e+06
#    Iteration :  21  (B r, r) = 1.21154e+06
#    Iteration :  22  (B r, r) = 705198
#    Iteration :  23  (B r, r) = 212076
#    Iteration :  24  (B r, r) = 51285.6
#    Iteration :  25  (B r, r) = 22353.4
#    Iteration :  26  (B r, r) = 10588.2
#    Iteration :  27  (B r, r) = 3319.81
#    Iteration :  28  (B r, r) = 1380.88
#    Iteration :  29  (B r, r) = 895.708
#    Iteration :  30  (B r, r) = 467.023
#    Iteration :  31  (B r, r) = 139.4
#    Iteration :  32  (B r, r) = 57.5073
#    Iteration :  33  (B r, r) = 52.9955
#    Iteration :  34  (B r, r) = 38.9357
#    Iteration :  35  (B r, r) = 15.0846
#    Iteration :  36  (B r, r) = 4.19779
#    Iteration :  37  (B r, r) = 0.843728
#    Iteration :  38  (B r, r) = 0.28858
#    Iteration :  39  (B r, r) = 0.107356
#    Iteration :  40  (B r, r) = 0.0564087
#    Iteration :  41  (B r, r) = 0.029772
#    Iteration :  42  (B r, r) = 0.0133124
#    Iteration :  43  (B r, r) = 0.00584738
#    Iteration :  44  (B r, r) = 0.00272133
#    Iteration :  45  (B r, r) = 0.000851972
#    Iteration :  46  (B r, r) = 0.000204684
#    Iteration :  47  (B r, r) = 5.20758e-05
#    Iteration :  48  (B r, r) = 1.4858e-05
#    Iteration :  49  (B r, r) = 5.39625e-06
#    Iteration :  50  (B r, r) = 1.19687e-06
#    Iteration :  51  (B r, r) = 2.3968e-07
#    Iteration :  52  (B r, r) = 4.64971e-08
#    Iteration :  53  (B r, r) = 1.19678e-08
# Average reduction factor = 0.768882
#    Iteration :   0  (B r, r) = 10122.8
#    Iteration :   1  (B r, r) = 1288.99
# Temperature:  19.00000010172589
#    Iteration :   2  (B r, r) = 519.264
#    Iteration :   3  (B r, r) = 344.235
#    Iteration :   4  (B r, r) = 323.234
#    Iteration :   5  (B r, r) = 268.376
#    Iteration :   6  (B r, r) = 230.749
#    Iteration :   7  (B r, r) = 218.345
#    Iteration :   8  (B r, r) = 238.717
#    Iteration :   9  (B r, r) = 333.107
#    Iteration :  10  (B r, r) = 720.606
#    Iteration :  11  (B r, r) = 862.041
#    Iteration :  12  (B r, r) = 611.066
#    Iteration :  13  (B r, r) = 419.158
#    Iteration :  14  (B r, r) = 222.672
#    Iteration :  15  (B r, r) = 124.997
#    Iteration :  16  (B r, r) = 163.94
#    Iteration :  17  (B r, r) = 396.924
#    Iteration :  18  (B r, r) = 903.274
#    Iteration :  19  (B r, r) = 1486.79
#    Iteration :  20  (B r, r) = 3749.91
#    Iteration :  21  (B r, r) = 10788.1
#    Iteration :  22  (B r, r) = 23875.7
#    Iteration :  23  (B r, r) = 36427.4
#    Iteration :  24  (B r, r) = 25457.3
#    Iteration :  25  (B r, r) = 15007.2
#    Iteration :  26  (B r, r) = 7576.2
#    Iteration :  27  (B r, r) = 2787.26
#    Iteration :  28  (B r, r) = 1375.65
#    Iteration :  29  (B r, r) = 827.128
#    Iteration :  30  (B r, r) = 413.92
#    Iteration :  31  (B r, r) = 126.389
#    Iteration :  32  (B r, r) = 58.1627
#    Iteration :  33  (B r, r) = 51.6133
#    Iteration :  34  (B r, r) = 38.0025
#    Iteration :  35  (B r, r) = 14.7509
#    Iteration :  36  (B r, r) = 4.06729
#    Iteration :  37  (B r, r) = 0.701185
#    Iteration :  38  (B r, r) = 0.205583
#    Iteration :  39  (B r, r) = 0.0558597
#    Iteration :  40  (B r, r) = 0.0204468
#    Iteration :  41  (B r, r) = 0.00657976
#    Iteration :  42  (B r, r) = 0.00224752
#    Iteration :  43  (B r, r) = 0.000739282
#    Iteration :  44  (B r, r) = 0.000490333
#    Iteration :  45  (B r, r) = 0.000277513
#    Iteration :  46  (B r, r) = 0.000116172
#    Iteration :  47  (B r, r) = 3.74326e-05
#    Iteration :  48  (B r, r) = 1.30049e-05
#    Iteration :  49  (B r, r) = 4.56701e-06
#    Iteration :  50  (B r, r) = 1.07881e-06
#    Iteration :  51  (B r, r) = 2.15656e-07
#    Iteration :  52  (B r, r) = 4.59129e-08
#    Iteration :  53  (B r, r) = 1.17302e-08
#    Iteration :  54  (B r, r) = 2.47653e-09

# %%
df = pd.DataFrame([{"True size": sol1[0], "Center temperature": sol1[1], "Power": sol1[2], "Vertex": sol1[3], "Radiator max temperature": sol1[4]}])
df.loc[len(df.index)] = sol2
df.loc[len(df.index)] = sol3
pd.set_option("display.precision", 6)
df
# Out:
#    True size  Center temperature     Power              Vertex  \
# 0       9500                19.0  0.000059  (2454, 2528, 1513)
# 1       4651                19.0  0.000065  (2171, 2483, 1537)
# 2       1563                19.0  0.000075  (2330, 2677, 1821)
#
#    Radiator max temperature
# 0                 78.795069
# 1                 83.614475
# 2                 83.097348

# %% [markdown]
# ## Просмотр результатов в ParaView

# %%
Image(url= "Screenshot from 2024-11-18 18-42-43.png", width=1000, height=1000)
# Out:
# <img src="Screenshot from 2024-11-18 18-42-43.png" width="1000" height="1000"/>

# %%
Image(url= "Screenshot from 2024-11-18 18-43-52.png", width=1000, height=1000)
# Out:
# <img src="Screenshot from 2024-11-18 18-43-52.png" width="1000" height="1000"/>

# %%
Image(url= "Screenshot from 2024-11-18 18-43-22.png", width=1000, height=1000)
# Out:
# <img src="Screenshot from 2024-11-18 18-43-22.png" width="1000" height="1000"/>

# %%
Image(url= "Screenshot from 2024-11-18 18-44-36.png", width=1000, height=1000)
# Out:
# <img src="Screenshot from 2024-11-18 18-44-36.png" width="1000" height="1000"/>
